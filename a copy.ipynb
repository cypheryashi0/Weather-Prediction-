# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 from google.colab import drive
#       2 drive.mount('/content/drive')
#
# ModuleNotFoundError: No module named 'google.colab'

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df1 = pd.read_csv("/content/drive/MyDrive/major project/new/humidity.csv")
df2 = pd.read_csv("/content/drive/MyDrive/major project/new/pressure.csv")
df3 = pd.read_csv("/content/drive/MyDrive/major project/new/temperature.csv")
df4 = pd.read_csv("/content/drive/MyDrive/major project/new/weather_description.csv")
df5 = pd.read_csv("/content/drive/MyDrive/major project/new/wind_direction.csv")
df6 = pd.read_csv("/content/drive/MyDrive/major project/new/wind_speed.csv")

# %%
datetime = df1['Albuquerque']
humidity = df1['Albuquerque']
pressure = df2['Albuquerque']
temperature = df3['Albuquerque']
wind_direction = df4['Albuquerque']
wind_speed = df5['Albuquerque']
weather_description = df6['Albuquerque']
alb = pd.DataFrame({'datetime': datetime,
                    'humidity': humidity,
                    'pressure': pressure,
                    'temperature': temperature,
                    'wind_direction': wind_direction,
                    'wind_speed': wind_speed,
                    'weather_description': weather_description,
                    })
alb.head()
alb.describe()
# Out:
#            datetime      humidity      pressure   temperature    wind_speed  \
# count  44543.000000  44543.000000  44797.000000  45252.000000  45252.000000
# mean      45.186157     45.186157   1012.292185    285.617856    199.878458
# std       23.336546     23.336546     39.049838      9.853484    104.462490
# min        5.000000      5.000000    810.000000    255.042333      0.000000
# 25%       26.000000     26.000000   1015.000000    277.970000    125.000000
# 50%       42.000000     42.000000   1021.000000    286.120000    210.000000
# 75%       63.000000     63.000000   1025.000000    292.835643    292.000000
# max      100.000000    100.000000   1054.000000    312.710000    360.000000
#
#        weather_description
# count         45249.000000
# mean              2.763685
# std               2.300933
# min               0.000000
# 25%               1.000000
# 50%               2.000000
# 75%               4.000000
# max              22.000000

# %%
dataframe = {}
for i in df1.columns:
    humidity = df1[i]
    pressure = df2[i]
    temperature = df3[i]
    wind_direction = df5[i]
    wind_speed = df6[i]
    weather_description = df4[i]
    j=i
    j = pd.DataFrame({
                        'humidity': humidity,
                        'pressure': pressure,
                        'temperature': temperature,
                        'wind_direction': wind_direction,
                        'wind_speed': wind_speed,
                        'weather_description': weather_description,
                        })
    dataframe[i] = j

# %%
for value in dataframe.values():
    print(value)
# Out:
#                   humidity             pressure          temperature  \
# 0      2012-10-01 12:00:00  2012-10-01 12:00:00  2012-10-01 12:00:00
# 1      2012-10-01 13:00:00  2012-10-01 13:00:00  2012-10-01 13:00:00
# 2      2012-10-01 14:00:00  2012-10-01 14:00:00  2012-10-01 14:00:00
# 3      2012-10-01 15:00:00  2012-10-01 15:00:00  2012-10-01 15:00:00
# 4      2012-10-01 16:00:00  2012-10-01 16:00:00  2012-10-01 16:00:00
# ...                    ...                  ...                  ...
# 45248  2017-11-29 20:00:00  2017-11-29 20:00:00  2017-11-29 20:00:00
# 45249  2017-11-29 21:00:00  2017-11-29 21:00:00  2017-11-29 21:00:00
# 45250  2017-11-29 22:00:00  2017-11-29 22:00:00  2017-11-29 22:00:00
# 45251  2017-11-29 23:00:00  2017-11-29 23:00:00  2017-11-29 23:00:00
# 45252  2017-11-30 00:00:00  2017-11-30 00:00:00  2017-11-30 00:00:00
#
#             wind_direction           wind_speed  weather_description
# 0      2012-10-01 12:00:00  2012-10-01 12:00:00  2012-10-01 12:00:00
# ...

# %%
al = dataframe['Albuquerque']
al.head()
# Out:
#    humidity  pressure  temperature  wind_direction  wind_speed  \
# 0       NaN       NaN          NaN             NaN         NaN
# 1      50.0    1024.0   285.120000           360.0         4.0
# 2      49.0    1024.0   285.154558           360.0         4.0
# 3      49.0    1024.0   285.233952           360.0         4.0
# 4      49.0    1024.0   285.313345           360.0         4.0
#
#   weather_description
# 0                 NaN
# 1        sky is clear
# 2        sky is clear
# 3        sky is clear
# 4        sky is clear

# %%
dataframe['Atlanta'].head()
# Out:
#    humidity  pressure  temperature  wind_direction  wind_speed  \
# 0       NaN       NaN          NaN             NaN         NaN
# 1      94.0    1006.0   294.030000           110.0         3.0
# 2      94.0    1006.0   294.035341           110.0         3.0
# 3      94.0    1006.0   294.049702           111.0         3.0
# 4      94.0    1006.0   294.064063           111.0         3.0
#
#   weather_description
# 0                 NaN
# 1          light rain
# 2     overcast clouds
# 3     overcast clouds
# 4     overcast clouds

# %%
dataframe['Albuquerque']
# Out:
#        humidity  pressure  temperature  wind_direction  wind_speed  \
# 0           NaN       NaN          NaN             NaN         NaN
# 1          50.0    1024.0   285.120000           360.0         4.0
# 2          49.0    1024.0   285.154558           360.0         4.0
# 3          49.0    1024.0   285.233952           360.0         4.0
# 4          49.0    1024.0   285.313345           360.0         4.0
# ...         ...       ...          ...             ...         ...
# 45248      37.0    1025.0   285.720000           217.0         1.0
# 45249      34.0    1024.0   286.450000           217.0         1.0
# 45250      32.0    1024.0   286.440000           190.0         1.0
# 45251      30.0    1024.0   286.140000           200.0         1.0
# 45252      34.0    1024.0   284.700000           230.0         2.0
#
#       weather_description
# 0                     NaN
# 1            sky is clear
# 2            sky is clear
# 3            sky is clear
# ...

# %%
datetime = pd.DataFrame(df1, columns=['datetime'])
datetime
# Out:
#                   datetime
# 0      2012-10-01 12:00:00
# 1      2012-10-01 13:00:00
# 2      2012-10-01 14:00:00
# 3      2012-10-01 15:00:00
# 4      2012-10-01 16:00:00
# ...                    ...
# 45248  2017-11-29 20:00:00
# 45249  2017-11-29 21:00:00
# 45250  2017-11-29 22:00:00
# 45251  2017-11-29 23:00:00
# 45252  2017-11-30 00:00:00
#
# [45253 rows x 1 columns]

# %%
datetime.dtypes
# Out:
# datetime    object
# dtype: object

# %%
datetime['datetime'] = pd.to_datetime(datetime['datetime'])

# %%
datetime
# Out:
#                  datetime
# 0     2012-10-01 12:00:00
# 1     2012-10-01 13:00:00
# 2     2012-10-01 14:00:00
# 3     2012-10-01 15:00:00
# 4     2012-10-01 16:00:00
# ...                   ...
# 45248 2017-11-29 20:00:00
# 45249 2017-11-29 21:00:00
# 45250 2017-11-29 22:00:00
# 45251 2017-11-29 23:00:00
# 45252 2017-11-30 00:00:00
#
# [45253 rows x 1 columns]

# %%
datetime['datetime'] = datetime['datetime'].dt.month

# %%
datetime
# Out:
#        datetime
# 0            10
# 1            10
# 2            10
# 3            10
# 4            10
# ...         ...
# 45248        11
# 45249        11
# 45250        11
# 45251        11
# 45252        11
#
# [45253 rows x 1 columns]

# %%
import copy
df = copy.deepcopy(dataframe)
for value in df.values():
    value.insert(0, 'month', datetime['datetime'], True)
df['Atlanta']
# Out:
#        month  humidity  pressure  temperature  wind_direction  wind_speed  \
# 0         10       NaN       NaN          NaN             NaN         NaN
# 1         10      94.0    1006.0   294.030000           110.0         3.0
# 2         10      94.0    1006.0   294.035341           110.0         3.0
# 3         10      94.0    1006.0   294.049702           111.0         3.0
# 4         10      94.0    1006.0   294.064063           111.0         3.0
# ...      ...       ...       ...          ...             ...         ...
# 45248     11      82.0    1024.0   290.040000           146.0         1.0
# 45249     11      73.0    1023.0   291.420000           100.0         1.0
# 45250     11      77.0    1023.0   291.840000           146.0         1.0
# 45251     11      82.0    1023.0   290.640000           126.0         1.0
# 45252     11     100.0    1024.0   287.740000           126.0         1.0
#
#       weather_description
# 0                     NaN
# ...

# %%
df
# Out:
# {'datetime':        month             humidity             pressure          temperature  \
#  0         10  2012-10-01 12:00:00  2012-10-01 12:00:00  2012-10-01 12:00:00
#  1         10  2012-10-01 13:00:00  2012-10-01 13:00:00  2012-10-01 13:00:00
#  2         10  2012-10-01 14:00:00  2012-10-01 14:00:00  2012-10-01 14:00:00
#  3         10  2012-10-01 15:00:00  2012-10-01 15:00:00  2012-10-01 15:00:00
#  4         10  2012-10-01 16:00:00  2012-10-01 16:00:00  2012-10-01 16:00:00
#  ...      ...                  ...                  ...                  ...
#  45248     11  2017-11-29 20:00:00  2017-11-29 20:00:00  2017-11-29 20:00:00
#  45249     11  2017-11-29 21:00:00  2017-11-29 21:00:00  2017-11-29 21:00:00
#  45250     11  2017-11-29 22:00:00  2017-11-29 22:00:00  2017-11-29 22:00:00
#  45251     11  2017-11-29 23:00:00  2017-11-29 23:00:00  2017-11-29 23:00:00
#  45252     11  2017-11-30 00:00:00  2017-11-30 00:00:00  2017-11-30 00:00:00
#
# ...

# %%
df['Albuquerque']
# Out:
#        month  humidity  pressure  temperature  wind_direction  wind_speed  \
# 0         10       NaN       NaN          NaN             NaN         NaN
# 1         10      50.0    1024.0   285.120000           360.0         4.0
# 2         10      49.0    1024.0   285.154558           360.0         4.0
# 3         10      49.0    1024.0   285.233952           360.0         4.0
# 4         10      49.0    1024.0   285.313345           360.0         4.0
# ...      ...       ...       ...          ...             ...         ...
# 45248     11      37.0    1025.0   285.720000           217.0         1.0
# 45249     11      34.0    1024.0   286.450000           217.0         1.0
# 45250     11      32.0    1024.0   286.440000           190.0         1.0
# 45251     11      30.0    1024.0   286.140000           200.0         1.0
# 45252     11      34.0    1024.0   284.700000           230.0         2.0
#
#       weather_description
# 0                     NaN
# ...

# %%
df['Albuquerque'].isnull().sum()
# Out:
# month                    0
# humidity               710
# pressure               456
# temperature              1
# wind_direction           1
# wind_speed               4
# weather_description      1
# dtype: int64

# %%
df['Albuquerque']['humidity'].unique()
# Out:
# array([ nan,  50.,  49.,  48.,  47.,  41.,  40.,  23.,  22.,  21.,  15.,
#         19.,  24.,  39.,  45.,  37.,  34.,  30.,  25.,  18.,  14.,  10.,
#         13.,  29.,  27.,  35.,  33.,  43.,  17.,  11.,  12.,   8.,   7.,
#          9.,  28.,  26.,  20.,  16.,  32.,  38.,  85.,  53.,  57.,  59.,
#         66.,  65.,  64.,  69.,  95.,  60.,  31.,  36.,  56.,  42.,  68.,
#         76.,  52.,  54.,  44.,  51.,  55.,  67.,  61.,  70.,  46.,   6.,
#          5.,  58.,  62.,  87.,  81.,  71.,  80.,  75.,  86.,  93., 100.,
#         63.,  74.,  83.,  79.,  73.,  77.,  92.,  78.,  72.,  82.,  84.,
#         90.,  88.,  94.,  89.,  96.,  91.,  98.,  97.,  99.])

# %%
sns.boxplot(df['Albuquerque'], x=df['Albuquerque']['humidity'])
# Out:
# <Axes: xlabel='humidity'>

# %%
sns.boxplot(df['Albuquerque'], x=df['Albuquerque']['pressure'])
# Out:
# <Axes: xlabel='pressure'>

# %%
df['Albuquerque']['humidity'].mean()
# Out:
# 45.18615719641694

# %%
df['Albuquerque']['humidity'] = df['Albuquerque']['humidity'].fillna(df['Albuquerque']['humidity'].mean())

# %%
df
# Out:
# {'datetime':        month             humidity             pressure          temperature  \
#  0         10  2012-10-01 12:00:00  2012-10-01 12:00:00  2012-10-01 12:00:00
#  1         10  2012-10-01 13:00:00  2012-10-01 13:00:00  2012-10-01 13:00:00
#  2         10  2012-10-01 14:00:00  2012-10-01 14:00:00  2012-10-01 14:00:00
#  3         10  2012-10-01 15:00:00  2012-10-01 15:00:00  2012-10-01 15:00:00
#  4         10  2012-10-01 16:00:00  2012-10-01 16:00:00  2012-10-01 16:00:00
#  ...      ...                  ...                  ...                  ...
#  45248     11  2017-11-29 20:00:00  2017-11-29 20:00:00  2017-11-29 20:00:00
#  45249     11  2017-11-29 21:00:00  2017-11-29 21:00:00  2017-11-29 21:00:00
#  45250     11  2017-11-29 22:00:00  2017-11-29 22:00:00  2017-11-29 22:00:00
#  45251     11  2017-11-29 23:00:00  2017-11-29 23:00:00  2017-11-29 23:00:00
#  45252     11  2017-11-30 00:00:00  2017-11-30 00:00:00  2017-11-30 00:00:00
#
# ...

# %%
df['Albuquerque'].isnull().sum()
# Out:
# month                    0
# humidity                 0
# pressure               456
# temperature              1
# wind_direction           1
# wind_speed               4
# weather_description      1
# dtype: int64

# %%
df['Albuquerque']['pressure'].median()
# Out:
# 1021.0

# %%
df['Albuquerque']['pressure'] = df['Albuquerque']['pressure'].fillna(df['Albuquerque']['pressure'].median())

# %%
df
# Out:
# {'datetime':        month             humidity             pressure          temperature  \
#  0         10  2012-10-01 12:00:00  2012-10-01 12:00:00  2012-10-01 12:00:00
#  1         10  2012-10-01 13:00:00  2012-10-01 13:00:00  2012-10-01 13:00:00
#  2         10  2012-10-01 14:00:00  2012-10-01 14:00:00  2012-10-01 14:00:00
#  3         10  2012-10-01 15:00:00  2012-10-01 15:00:00  2012-10-01 15:00:00
#  4         10  2012-10-01 16:00:00  2012-10-01 16:00:00  2012-10-01 16:00:00
#  ...      ...                  ...                  ...                  ...
#  45248     11  2017-11-29 20:00:00  2017-11-29 20:00:00  2017-11-29 20:00:00
#  45249     11  2017-11-29 21:00:00  2017-11-29 21:00:00  2017-11-29 21:00:00
#  45250     11  2017-11-29 22:00:00  2017-11-29 22:00:00  2017-11-29 22:00:00
#  45251     11  2017-11-29 23:00:00  2017-11-29 23:00:00  2017-11-29 23:00:00
#  45252     11  2017-11-30 00:00:00  2017-11-30 00:00:00  2017-11-30 00:00:00
#
# ...

# %%
df['Albuquerque']['pressure'].isnull().sum()
# Out:
# 0

# %%
df
# Out:
# {'datetime':        month             humidity             pressure          temperature  \
#  0         10  2012-10-01 12:00:00  2012-10-01 12:00:00  2012-10-01 12:00:00
#  1         10  2012-10-01 13:00:00  2012-10-01 13:00:00  2012-10-01 13:00:00
#  2         10  2012-10-01 14:00:00  2012-10-01 14:00:00  2012-10-01 14:00:00
#  3         10  2012-10-01 15:00:00  2012-10-01 15:00:00  2012-10-01 15:00:00
#  4         10  2012-10-01 16:00:00  2012-10-01 16:00:00  2012-10-01 16:00:00
#  ...      ...                  ...                  ...                  ...
#  45248     11  2017-11-29 20:00:00  2017-11-29 20:00:00  2017-11-29 20:00:00
#  45249     11  2017-11-29 21:00:00  2017-11-29 21:00:00  2017-11-29 21:00:00
#  45250     11  2017-11-29 22:00:00  2017-11-29 22:00:00  2017-11-29 22:00:00
#  45251     11  2017-11-29 23:00:00  2017-11-29 23:00:00  2017-11-29 23:00:00
#  45252     11  2017-11-30 00:00:00  2017-11-30 00:00:00  2017-11-30 00:00:00
#
# ...

# %%
x =0
for i in df.values():
    x = x+1
print(x)
# Out:
# 37

# %%
dfn = copy.deepcopy(df)
dfn
# Out:
# {'datetime':        month             humidity             pressure          temperature  \
#  0         10  2012-10-01 12:00:00  2012-10-01 12:00:00  2012-10-01 12:00:00
#  1         10  2012-10-01 13:00:00  2012-10-01 13:00:00  2012-10-01 13:00:00
#  2         10  2012-10-01 14:00:00  2012-10-01 14:00:00  2012-10-01 14:00:00
#  3         10  2012-10-01 15:00:00  2012-10-01 15:00:00  2012-10-01 15:00:00
#  4         10  2012-10-01 16:00:00  2012-10-01 16:00:00  2012-10-01 16:00:00
#  ...      ...                  ...                  ...                  ...
#  45248     11  2017-11-29 20:00:00  2017-11-29 20:00:00  2017-11-29 20:00:00
#  45249     11  2017-11-29 21:00:00  2017-11-29 21:00:00  2017-11-29 21:00:00
#  45250     11  2017-11-29 22:00:00  2017-11-29 22:00:00  2017-11-29 22:00:00
#  45251     11  2017-11-29 23:00:00  2017-11-29 23:00:00  2017-11-29 23:00:00
#  45252     11  2017-11-30 00:00:00  2017-11-30 00:00:00  2017-11-30 00:00:00
#
# ...

# %%
for df_name, datafr in dfn.items():
    print(f"Null values in {df_name}:")
    for column in datafr.columns:
        null_values = datafr[column].isnull().sum()
        print(f"Column {column}: {null_values} null values")
# Out:
# Null values in datetime:
# Column month: 0 null values
# Column humidity: 0 null values
# Column pressure: 0 null values
# Column temperature: 0 null values
# Column wind_direction: 0 null values
# Column wind_speed: 0 null values
# Column weather_description: 0 null values
# Null values in Vancouver:
# Column month: 0 null values
# Column humidity: 1826 null values
# Column pressure: 4234 null values
# Column temperature: 795 null values
# Column wind_direction: 795 null values
# Column wind_speed: 795 null values
# Column weather_description: 793 null values
# Null values in Portland:
# Column month: 0 null values
# Column humidity: 449 null values
# Column pressure: 4 null values
# Column temperature: 1 null values
# Column wind_direction: 1 null values
# Column wind_speed: 1 null values
# Column weather_description: 1 null values
# Null values in San Francisco:
# Column month: 0 null values
# Column humidity: 942 null values
# Column pressure: 815 null values
# ...

# %%
df
# Out:
# {'datetime':        month             humidity             pressure          temperature  \
#  0         10  2012-10-01 12:00:00  2012-10-01 12:00:00  2012-10-01 12:00:00
#  1         10  2012-10-01 13:00:00  2012-10-01 13:00:00  2012-10-01 13:00:00
#  2         10  2012-10-01 14:00:00  2012-10-01 14:00:00  2012-10-01 14:00:00
#  3         10  2012-10-01 15:00:00  2012-10-01 15:00:00  2012-10-01 15:00:00
#  4         10  2012-10-01 16:00:00  2012-10-01 16:00:00  2012-10-01 16:00:00
#  ...      ...                  ...                  ...                  ...
#  45248     11  2017-11-29 20:00:00  2017-11-29 20:00:00  2017-11-29 20:00:00
#  45249     11  2017-11-29 21:00:00  2017-11-29 21:00:00  2017-11-29 21:00:00
#  45250     11  2017-11-29 22:00:00  2017-11-29 22:00:00  2017-11-29 22:00:00
#  45251     11  2017-11-29 23:00:00  2017-11-29 23:00:00  2017-11-29 23:00:00
#  45252     11  2017-11-30 00:00:00  2017-11-30 00:00:00  2017-11-30 00:00:00
#
# ...

# %%
dfn
# Out:
# {'datetime':        month             humidity             pressure          temperature  \
#  0         10  2012-10-01 12:00:00  2012-10-01 12:00:00  2012-10-01 12:00:00
#  1         10  2012-10-01 13:00:00  2012-10-01 13:00:00  2012-10-01 13:00:00
#  2         10  2012-10-01 14:00:00  2012-10-01 14:00:00  2012-10-01 14:00:00
#  3         10  2012-10-01 15:00:00  2012-10-01 15:00:00  2012-10-01 15:00:00
#  4         10  2012-10-01 16:00:00  2012-10-01 16:00:00  2012-10-01 16:00:00
#  ...      ...                  ...                  ...                  ...
#  45248     11  2017-11-29 20:00:00  2017-11-29 20:00:00  2017-11-29 20:00:00
#  45249     11  2017-11-29 21:00:00  2017-11-29 21:00:00  2017-11-29 21:00:00
#  45250     11  2017-11-29 22:00:00  2017-11-29 22:00:00  2017-11-29 22:00:00
#  45251     11  2017-11-29 23:00:00  2017-11-29 23:00:00  2017-11-29 23:00:00
#  45252     11  2017-11-30 00:00:00  2017-11-30 00:00:00  2017-11-30 00:00:00
#
# ...

# %%
x = 0
for i in dfn.values():
    x=x+1
print(x)
# Out:
# 37

# %%
dfn.pop('datetime')
dfn
# Out:
# {'Vancouver':        month  humidity  pressure  temperature  wind_direction  wind_speed  \
#  0         10       NaN       NaN          NaN             NaN         NaN
#  1         10      76.0       NaN   284.630000             0.0         0.0
#  2         10      76.0       NaN   284.629041             6.0         0.0
#  3         10      76.0       NaN   284.626998            20.0         0.0
#  4         10      77.0       NaN   284.624955            34.0         0.0
#  ...      ...       ...       ...          ...             ...         ...
#  45248     11       NaN       NaN          NaN             NaN         NaN
#  45249     11       NaN       NaN          NaN             NaN         NaN
#  45250     11       NaN       NaN          NaN             NaN         NaN
#  45251     11       NaN       NaN          NaN             NaN         NaN
#  45252     11       NaN       NaN          NaN             NaN         NaN
#
#        weather_description
#  0                     NaN
# ...

# %%
# Create subplots
fig, axes = plt.subplots(nrows=12, ncols=3, figsize=(15, 50))

# Flatten the axes array for easier indexing
axes = axes.flatten()

# Plot boxplots for each dataframe in the dictionary
for i, (group, dataf) in enumerate(dfn.items()):
    dataf.boxplot(ax=axes[i], vert=False, boxprops=dict(color='white'), flierprops=dict(marker='o', markerfacecolor='red', markeredgecolor='red'), grid=False)
    axes[i].set_title(f'Boxplot for {group}')

# Adjust layout
plt.tight_layout()

# Show plot
plt.show()

# %%
df['Albuquerque']['weather_description'].value_counts()
# Out:
# weather_description
# sky is clear                           18344
# broken clouds                           7567
# few clouds                              6371
# scattered clouds                        6294
# overcast clouds                         2197
# light rain                              2087
# moderate rain                            634
# light snow                               246
# proximity thunderstorm                   235
# proximity shower rain                    174
# snow                                     154
# thunderstorm                             152
# mist                                     137
# heavy intensity rain                     133
# fog                                       82
# dust                                      79
# light intensity drizzle                   61
# haze                                      53
# thunderstorm with light rain              46
# shower rain                               35
# ...

# %%
# Create subplots
fig, axes = plt.subplots(nrows=12, ncols=3, figsize=(15, 50))

# Plot correlation heatmaps for each dataframe in the dictionary
for (group, dataf), ax in zip(dfn.items(), axes.flatten()):
    # Select only numerical columns for correlation calculation
    numerical_data = dataf.select_dtypes(include='number')

    # Calculate correlation matrix
    correlation_matrix = numerical_data.corr()

    # Plot heatmap
    sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt='.2f', linewidths=0.5, ax=ax)
    ax.set_title(f'Correlation Heatmap for {group}')

# Adjust layout
plt.tight_layout()

# Show plot
plt.show()

# %%
## Assuming your dataframes are stored in a dictionary called dataframes_dict
#for df_name, dataf in dfn.items():
#    if 'weather_description' in dataf.columns:
#        dataf.drop('weather_description', axis=1, inplace=True)
#dfn

# %%
df['Albuquerque']
# Out:
#        month   humidity  pressure  temperature  wind_direction  wind_speed  \
# 0         10  45.186157    1021.0          NaN             NaN         NaN
# 1         10  50.000000    1024.0   285.120000           360.0         4.0
# 2         10  49.000000    1024.0   285.154558           360.0         4.0
# 3         10  49.000000    1024.0   285.233952           360.0         4.0
# 4         10  49.000000    1024.0   285.313345           360.0         4.0
# ...      ...        ...       ...          ...             ...         ...
# 45248     11  37.000000    1025.0   285.720000           217.0         1.0
# 45249     11  34.000000    1024.0   286.450000           217.0         1.0
# 45250     11  32.000000    1024.0   286.440000           190.0         1.0
# 45251     11  30.000000    1024.0   286.140000           200.0         1.0
# 45252     11  34.000000    1024.0   284.700000           230.0         2.0
#
#       weather_description
# 0                     NaN
# ...

# %%
for df_name, datafr in dfn.items():
    for column in datafr.columns:
        if column=='weather_description':
            dfn[df_name][column] = dfn[df_name][column].fillna(dfn[df_name][column].mode()[0])
        else:
            dfn[df_name][column] = dfn[df_name][column].fillna(dfn[df_name][column].median())

# %%
dfn['Albuquerque']
# Out:
#        month   humidity  pressure  temperature  wind_direction  wind_speed  \
# 0         10  45.186157    1021.0   286.120000           210.0         2.0
# 1         10  50.000000    1024.0   285.120000           360.0         4.0
# 2         10  49.000000    1024.0   285.154558           360.0         4.0
# 3         10  49.000000    1024.0   285.233952           360.0         4.0
# 4         10  49.000000    1024.0   285.313345           360.0         4.0
# ...      ...        ...       ...          ...             ...         ...
# 45248     11  37.000000    1025.0   285.720000           217.0         1.0
# 45249     11  34.000000    1024.0   286.450000           217.0         1.0
# 45250     11  32.000000    1024.0   286.440000           190.0         1.0
# 45251     11  30.000000    1024.0   286.140000           200.0         1.0
# 45252     11  34.000000    1024.0   284.700000           230.0         2.0
#
#       weather_description
# 0            sky is clear
# ...

# %%
for df_name, datafr in dfn.items():
    print(f"Null values in {df_name}:")
    for column in datafr.columns:
        null_values = datafr[column].isnull().sum()
        print(f"Column {column}: {null_values} null values")
# Out:
# Null values in Vancouver:
# Column month: 0 null values
# Column humidity: 0 null values
# Column pressure: 0 null values
# Column temperature: 0 null values
# Column wind_direction: 0 null values
# Column wind_speed: 0 null values
# Column weather_description: 0 null values
# Null values in Portland:
# Column month: 0 null values
# Column humidity: 0 null values
# Column pressure: 0 null values
# Column temperature: 0 null values
# Column wind_direction: 0 null values
# Column wind_speed: 0 null values
# Column weather_description: 0 null values
# Null values in San Francisco:
# Column month: 0 null values
# Column humidity: 0 null values
# Column pressure: 0 null values
# Column temperature: 0 null values
# Column wind_direction: 0 null values
# Column wind_speed: 0 null values
# Column weather_description: 0 null values
# Null values in Seattle:
# Column month: 0 null values
# Column humidity: 0 null values
# Column pressure: 0 null values
# Column temperature: 0 null values
# ...

# %%
dfn['Albuquerque']['weather_description'].nunique()
# Out:
# 37

# %% [markdown]
# n = np.array([[1, 2, 3], [4, 5, 6]])
# q = n.flatten()
# q

# %%
#from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import MinMaxScaler

# Create MinMaxScaler instance
scaler = MinMaxScaler()
#scaler = StandardScaler()
label = LabelEncoder()

# %%
for df_name, datafr in dfn.items():
    for column in datafr.columns:
        if column=='weather_description':
            dfn[df_name][column] = label.fit_transform(dfn[df_name][column].values.reshape(-1, 1))
        else:
            dfn[df_name][column] = scaler.fit_transform(dfn[df_name][column].values.reshape(-1, 1))
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/preprocessing/_label.py:116: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /usr/local/lib/python3.10/dist-packages/sklearn/preprocessing/_label.py:116: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /usr/local/lib/python3.10/dist-packages/sklearn/preprocessing/_label.py:116: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# ...

# %%
dfn['Albuquerque']
# Out:
#           month  humidity  pressure  temperature  wind_direction  wind_speed  \
# 0      0.818182  0.423012  0.864754     0.538910        0.583333    0.090909
# 1      0.818182  0.473684  0.877049     0.521569        1.000000    0.181818
# 2      0.818182  0.463158  0.877049     0.522168        1.000000    0.181818
# 3      0.818182  0.463158  0.877049     0.523545        1.000000    0.181818
# 4      0.818182  0.463158  0.877049     0.524922        1.000000    0.181818
# ...         ...       ...       ...          ...             ...         ...
# 45248  0.909091  0.336842  0.881148     0.531973        0.602778    0.045455
# 45249  0.909091  0.305263  0.877049     0.544632        0.602778    0.045455
# 45250  0.909091  0.284211  0.877049     0.544459        0.527778    0.045455
# 45251  0.909091  0.263158  0.877049     0.539257        0.555556    0.045455
# 45252  0.909091  0.305263  0.877049     0.514286        0.638889    0.090909
#
#        weather_description
# ...

# %%
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.neighbors import KNeighborsRegressor
from sklearn.metrics import r2_score, mean_squared_error

# %%
alb = copy.deepcopy(dfn['Albuquerque'])
alb
# Out:
#           month  humidity  pressure  temperature  wind_direction  wind_speed  \
# 0      0.818182  0.423012  0.864754     0.538910        0.583333    0.090909
# 1      0.818182  0.473684  0.877049     0.521569        1.000000    0.181818
# 2      0.818182  0.463158  0.877049     0.522168        1.000000    0.181818
# 3      0.818182  0.463158  0.877049     0.523545        1.000000    0.181818
# 4      0.818182  0.463158  0.877049     0.524922        1.000000    0.181818
# ...         ...       ...       ...          ...             ...         ...
# 45248  0.909091  0.336842  0.881148     0.531973        0.602778    0.045455
# 45249  0.909091  0.305263  0.877049     0.544632        0.602778    0.045455
# 45250  0.909091  0.284211  0.877049     0.544459        0.527778    0.045455
# 45251  0.909091  0.263158  0.877049     0.539257        0.555556    0.045455
# 45252  0.909091  0.305263  0.877049     0.514286        0.638889    0.090909
#
#        weather_description
# ...

# %%
x = alb.drop(['weather_description'], axis=1)
y = alb['weather_description']

# %%
x
# Out:
#           month  humidity  pressure  temperature  wind_direction  wind_speed
# 0      0.818182  0.423012  0.864754     0.538910        0.583333    0.090909
# 1      0.818182  0.473684  0.877049     0.521569        1.000000    0.181818
# 2      0.818182  0.463158  0.877049     0.522168        1.000000    0.181818
# 3      0.818182  0.463158  0.877049     0.523545        1.000000    0.181818
# 4      0.818182  0.463158  0.877049     0.524922        1.000000    0.181818
# ...         ...       ...       ...          ...             ...         ...
# 45248  0.909091  0.336842  0.881148     0.531973        0.602778    0.045455
# 45249  0.909091  0.305263  0.877049     0.544632        0.602778    0.045455
# 45250  0.909091  0.284211  0.877049     0.544459        0.527778    0.045455
# 45251  0.909091  0.263158  0.877049     0.539257        0.555556    0.045455
# 45252  0.909091  0.305263  0.877049     0.514286        0.638889    0.090909
#
# [45253 rows x 6 columns]

# %%
y
# Out:
# 0        26
# 1        26
# 2        26
# 3        26
# 4        26
#          ..
# 45248     0
# 45249     0
# 45250     0
# 45251    15
# 45252    15
# Name: weather_description, Length: 45253, dtype: int64

# %%
y.unique()
# Out:
# array([26,  3, 23,  0, 15, 11, 14, 17, 16, 28, 10, 24, 13,  4,  8, 21, 27,
#         2, 12, 34, 31,  5,  7, 30, 33, 35, 18,  1, 36,  9, 29, 25, 20, 22,
#        19,  6, 32])

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.naive_bayes import MultinomialNB
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import AdaBoostClassifier
from sklearn.ensemble import BaggingClassifier
from sklearn.ensemble import ExtraTreesClassifier
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
from sklearn.discriminant_analysis import QuadraticDiscriminantAnalysis
from xgboost import XGBClassifier

# %%
X_train,X_test,y_train,y_test = train_test_split(x,y,test_size=0.2,random_state=2)

# %%
svc = SVC(kernel='sigmoid', gamma=1.0)
knc = KNeighborsClassifier()
mnb = MultinomialNB()
dtc = DecisionTreeClassifier(max_depth=5)
lrc = LogisticRegression(solver='liblinear', penalty='l1')
rfc = RandomForestClassifier(n_estimators=50, random_state=2)
abc = AdaBoostClassifier(n_estimators=50, random_state=2)
bc = BaggingClassifier(n_estimators=50, random_state=2)
etc = ExtraTreesClassifier(n_estimators=50, random_state=2)
gbdt = GradientBoostingClassifier(n_estimators=50,random_state=2)
gnb = GaussianNB()
lda  = LinearDiscriminantAnalysis()

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score

# %%
clfs = {
    #'SVC' : svc,
    'KN' : knc,
    'NB': mnb,
    'DT': dtc,
    'LR': lrc,
    'RF': rfc,
    'AdaBoost': abc,
    'BgC': bc,
    'ETC': etc,
    'GBDT':gbdt,
    'GNB' :gnb,
    'LDA' : lda,
}

# %%
def train_classifier(clf,X_train,y_train,X_test,y_test):
    clf.fit(X_train,y_train)
    y_pred = clf.predict(X_test)
    accuracy = accuracy_score(y_test,y_pred)
    precision = precision_score(y_test,y_pred, average='macro')
    recall = recall_score(y_test,y_pred, average='macro')
    f1 = f1_score(y_test,y_pred, average='macro')
    return accuracy,precision, recall, f1

# %%
# train_classifier(svc,X_train,y_train,X_test,y_test)

# %%
# train_classifier(rfc,X_train,y_train,X_test,y_test)

# %%
y.unique()
# Out:
# array([26,  3, 23,  0, 15, 11, 14, 17, 16, 28, 10, 24, 13,  4,  8, 21, 27,
#         2, 12, 34, 31,  5,  7, 30, 33, 35, 18,  1, 36,  9, 29, 25, 20, 22,
#        19,  6, 32])

# %%
accuracy_scores = []
precision_scores = []
recall_scores = []
f1_scores = []

for name,clf in clfs.items():
    current_accuracy,current_precision, current_recall, current_f1 = train_classifier(clf, X_train,y_train,X_test,y_test)

    print("For ",name)
    print("Accuracy - ",current_accuracy)
    print("Precision - ",current_precision)
    print("Recall  - ", current_recall)
    print("F1 Score - ", current_f1)

    accuracy_scores.append(current_accuracy)
    precision_scores.append(current_precision)
    recall_scores.append(current_recall)
    f1_scores.append(current_f1)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# For  KN
# Accuracy -  0.4438183626118661
# Precision -  0.1590510052785167
# Recall  -  0.12688924977441454
# F1 Score -  0.1384425235945061
# For  NB
# Accuracy -  0.4030493868080875
# Precision -  0.013001593122841533
# Recall  -  0.03225806451612903
# F1 Score -  0.01853333638157945
# ...

# %%
performance_df = pd.DataFrame({'Algorithm':clfs.keys(),'Accuracy':accuracy_scores,'Precision':precision_scores, 'Recall' : recall_scores, 'F1' : f1_scores}).sort_values('Precision',ascending=False)

# %%
performance_df
# Out:
#    Algorithm  Accuracy  Precision    Recall        F1
# 7        ETC  0.540161   0.268781  0.191944  0.211517
# 4         RF  0.532096   0.255280  0.186219  0.209388
# 6        BgC  0.521600   0.246053  0.185228  0.205644
# 0         KN  0.443818   0.159051  0.126889  0.138443
# 8       GBDT  0.450668   0.110582  0.071195  0.075240
# 10       LDA  0.421942   0.099221  0.065528  0.042974
# 9        GNB  0.385482   0.078127  0.111647  0.065463
# 3         LR  0.424152   0.068955  0.041224  0.033991
# 2         DT  0.427798   0.067429  0.049881  0.047376
# 1         NB  0.403049   0.013002  0.032258  0.018533
# 5   AdaBoost  0.396089   0.012926  0.031701  0.018364

# %%
df['Albuquerque']['weather_description'].unique()
# Out:
# array([nan, 'sky is clear', 'few clouds', 'scattered clouds',
#        'broken clouds', 'overcast clouds', 'light rain', 'moderate rain',
#        'proximity shower rain', 'proximity moderate rain', 'smoke',
#        'light intensity shower rain', 'shower rain', 'mist', 'fog',
#        'heavy snow', 'sand', 'sleet', 'dust', 'light snow',
#        'thunderstorm with light rain', 'thunderstorm', 'haze',
#        'heavy intensity rain', 'squalls', 'thunderstorm with heavy rain',
#        'thunderstorm with rain', 'proximity thunderstorm', 'drizzle',
#        'very heavy rain', 'light intensity drizzle', 'snow',
#        'shower snow', 'proximity thunderstorm with rain',
#        'sand/dust whirls', 'proximity thunderstorm with drizzle',
#        'heavy intensity drizzle', 'thunderstorm with drizzle'],
#       dtype=object)

# %%
def map_classes(target):
    if type(target) == float:
        target = str(target)
    if 'squall' in target or 'thunderstorm' in target:
        return 'thunderstorm'
    elif 'drizzle' in target or 'rain' in target:
        return 'rain'
    elif 'sleet' in target or 'snow' in target:
        return 'snowy'
    elif 'cloud' in target:
        return 'cloudy'
    elif 'fog' in target or 'mist' in target or 'haze' in target:
        return 'foggy'
    elif 'sun' in target or 'clear' in target:
        return 'sunny'

# Apply the mapping function to create a new target variable with decreased classes
df['Albuquerque']['weather_desc'] = df['Albuquerque']['weather_description'].apply(map_classes)

# Display the DataFrame with the new target variable
print(df['Albuquerque'])
# Out:
#        month   humidity  pressure  temperature  wind_direction  wind_speed  \
# 0         10  45.186157    1021.0          NaN             NaN         NaN
# 1         10  50.000000    1024.0   285.120000           360.0         4.0
# 2         10  49.000000    1024.0   285.154558           360.0         4.0
# 3         10  49.000000    1024.0   285.233952           360.0         4.0
# 4         10  49.000000    1024.0   285.313345           360.0         4.0
# ...      ...        ...       ...          ...             ...         ...
# 45248     11  37.000000    1025.0   285.720000           217.0         1.0
# 45249     11  34.000000    1024.0   286.450000           217.0         1.0
# 45250     11  32.000000    1024.0   286.440000           190.0         1.0
# 45251     11  30.000000    1024.0   286.140000           200.0         1.0
# 45252     11  34.000000    1024.0   284.700000           230.0         2.0
#
#       weather_description weather_desc
# ...

# %%
df['Albuquerque']['weather_desc'].unique()
# Out:
# array([None, 'sunny', 'cloudy', 'rain', 'foggy', 'snowy', 'thunderstorm'],
#       dtype=object)

# %%
dfn['Albuquerque'] = copy.deepcopy(df['Albuquerque'])
dfn['Albuquerque']
# Out:
#        month   humidity  pressure  temperature  wind_direction  wind_speed  \
# 0         10  45.186157    1021.0          NaN             NaN         NaN
# 1         10  50.000000    1024.0   285.120000           360.0         4.0
# 2         10  49.000000    1024.0   285.154558           360.0         4.0
# 3         10  49.000000    1024.0   285.233952           360.0         4.0
# 4         10  49.000000    1024.0   285.313345           360.0         4.0
# ...      ...        ...       ...          ...             ...         ...
# 45248     11  37.000000    1025.0   285.720000           217.0         1.0
# 45249     11  34.000000    1024.0   286.450000           217.0         1.0
# 45250     11  32.000000    1024.0   286.440000           190.0         1.0
# 45251     11  30.000000    1024.0   286.140000           200.0         1.0
# 45252     11  34.000000    1024.0   284.700000           230.0         2.0
#
#       weather_description weather_desc
# ...

# %%
dfn['Albuquerque'] = dfn['Albuquerque'].drop(columns = ['weather_description'])
dfn['Albuquerque']
# Out:
#        month   humidity  pressure  temperature  wind_direction  wind_speed  \
# 0         10  45.186157    1021.0          NaN             NaN         NaN
# 1         10  50.000000    1024.0   285.120000           360.0         4.0
# 2         10  49.000000    1024.0   285.154558           360.0         4.0
# 3         10  49.000000    1024.0   285.233952           360.0         4.0
# 4         10  49.000000    1024.0   285.313345           360.0         4.0
# ...      ...        ...       ...          ...             ...         ...
# 45248     11  37.000000    1025.0   285.720000           217.0         1.0
# 45249     11  34.000000    1024.0   286.450000           217.0         1.0
# 45250     11  32.000000    1024.0   286.440000           190.0         1.0
# 45251     11  30.000000    1024.0   286.140000           200.0         1.0
# 45252     11  34.000000    1024.0   284.700000           230.0         2.0
#
#       weather_desc
# 0             None
# 1            sunny
# ...

# %%
for df_name, datafr in dfn.items():
    for column in datafr.columns:
        if column=='weather_desc':
            dfn[df_name][column] = dfn[df_name][column].fillna(dfn[df_name][column].mode()[0])
        else:
            dfn[df_name][column] = dfn[df_name][column].fillna(dfn[df_name][column].median())

# %%
for df_name, datafr in dfn.items():
    for column in datafr.columns:
        if column=='weather_desc':
            dfn[df_name][column] = label.fit_transform(dfn[df_name][column].values.reshape(-1, 1))
        else:
            dfn[df_name][column] = scaler.fit_transform(dfn[df_name][column].values.reshape(-1, 1))
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/preprocessing/_label.py:116: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)

# %%
dfn['Albuquerque']
# Out:
#           month  humidity  pressure  temperature  wind_direction  wind_speed  \
# 0      0.818182  0.423012  0.864754     0.538910        0.583333    0.090909
# 1      0.818182  0.473684  0.877049     0.521569        1.000000    0.181818
# 2      0.818182  0.463158  0.877049     0.522168        1.000000    0.181818
# 3      0.818182  0.463158  0.877049     0.523545        1.000000    0.181818
# 4      0.818182  0.463158  0.877049     0.524922        1.000000    0.181818
# ...         ...       ...       ...          ...             ...         ...
# 45248  0.909091  0.336842  0.881148     0.531973        0.602778    0.045455
# 45249  0.909091  0.305263  0.877049     0.544632        0.602778    0.045455
# 45250  0.909091  0.284211  0.877049     0.544459        0.527778    0.045455
# 45251  0.909091  0.263158  0.877049     0.539257        0.555556    0.045455
# 45252  0.909091  0.305263  0.877049     0.514286        0.638889    0.090909
#
#        weather_desc
# 0                 0
# ...

# %%
alb1 = copy.deepcopy(dfn['Albuquerque'])
alb1
# Out:
#           month  humidity  pressure  temperature  wind_direction  wind_speed  \
# 0      0.818182  0.423012  0.864754     0.538910        0.583333    0.090909
# 1      0.818182  0.473684  0.877049     0.521569        1.000000    0.181818
# 2      0.818182  0.463158  0.877049     0.522168        1.000000    0.181818
# 3      0.818182  0.463158  0.877049     0.523545        1.000000    0.181818
# 4      0.818182  0.463158  0.877049     0.524922        1.000000    0.181818
# ...         ...       ...       ...          ...             ...         ...
# 45248  0.909091  0.336842  0.881148     0.531973        0.602778    0.045455
# 45249  0.909091  0.305263  0.877049     0.544632        0.602778    0.045455
# 45250  0.909091  0.284211  0.877049     0.544459        0.527778    0.045455
# 45251  0.909091  0.263158  0.877049     0.539257        0.555556    0.045455
# 45252  0.909091  0.305263  0.877049     0.514286        0.638889    0.090909
#
#        weather_desc
# 0                 0
# ...

# %%
x = alb1.drop(['weather_desc'], axis=1)
y = alb1['weather_desc']

# %%
x
# Out:
#           month  humidity  pressure  temperature  wind_direction  wind_speed
# 0      0.818182  0.423012  0.864754     0.538910        0.583333    0.090909
# 1      0.818182  0.473684  0.877049     0.521569        1.000000    0.181818
# 2      0.818182  0.463158  0.877049     0.522168        1.000000    0.181818
# 3      0.818182  0.463158  0.877049     0.523545        1.000000    0.181818
# 4      0.818182  0.463158  0.877049     0.524922        1.000000    0.181818
# ...         ...       ...       ...          ...             ...         ...
# 45248  0.909091  0.336842  0.881148     0.531973        0.602778    0.045455
# 45249  0.909091  0.305263  0.877049     0.544632        0.602778    0.045455
# 45250  0.909091  0.284211  0.877049     0.544459        0.527778    0.045455
# 45251  0.909091  0.263158  0.877049     0.539257        0.555556    0.045455
# 45252  0.909091  0.305263  0.877049     0.514286        0.638889    0.090909
#
# [45253 rows x 6 columns]

# %%
y
# Out:
# 0        0
# 1        4
# 2        4
# 3        4
# 4        4
#         ..
# 45248    0
# 45249    0
# 45250    0
# 45251    0
# 45252    0
# Name: weather_desc, Length: 45253, dtype: int64

# %%
y.unique()
# Out:
# array([0, 4, 2, 1, 3, 5])

# %%
y.value_counts()
# Out:
# weather_desc
# 0    22548
# 4    18344
# 2     3185
# 5      482
# 3      422
# 1      272
# Name: count, dtype: int64

# %%
X_train,X_test,y_train,y_test = train_test_split(x,y,test_size=0.2,random_state=2)

# %%
svc = SVC(kernel='sigmoid', gamma=1.0)
knc = KNeighborsClassifier()
mnb = MultinomialNB()
dtc = DecisionTreeClassifier(max_depth=5)
lrc = LogisticRegression(solver='liblinear', penalty='l1')
rfc = RandomForestClassifier(n_estimators=50, random_state=2)
abc = AdaBoostClassifier(n_estimators=50, random_state=2)
bc = BaggingClassifier(n_estimators=50, random_state=2)
etc = ExtraTreesClassifier(n_estimators=50, random_state=2)
gbdt = GradientBoostingClassifier(n_estimators=50,random_state=2)
gnb = GaussianNB()
lda  = LinearDiscriminantAnalysis()

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score

# %%
clfs = {
    #'SVC' : svc,
    'KN' : knc,
    'NB': mnb,
    'DT': dtc,
    'LR': lrc,
    'RF': rfc,
    'AdaBoost': abc,
    'BgC': bc,
    'ETC': etc,
    'GBDT':gbdt,
    'GNB' :gnb,
    'LDA' : lda,
}

# %%
def train_classifier(clf,X_train,y_train,X_test,y_test):
    clf.fit(X_train,y_train)
    y_pred = clf.predict(X_test)
    accuracy = accuracy_score(y_test,y_pred)
    precision = precision_score(y_test,y_pred, average='macro')
    recall = recall_score(y_test,y_pred, average='macro')
    f1 = f1_score(y_test,y_pred, average='macro')
    return accuracy,precision, recall, f1

# %%
accuracy_scores = []
precision_scores = []
recall_scores = []
f1_scores = []

for name,clf in clfs.items():
    current_accuracy,current_precision, current_recall, current_f1 = train_classifier(clf, X_train,y_train,X_test,y_test)

    print("For ",name)
    print("Accuracy - ",current_accuracy)
    print("Precision - ",current_precision)
    print("Recall  - ", current_recall)
    print("F1 Score - ", current_f1)

    accuracy_scores.append(current_accuracy)
    precision_scores.append(current_precision)
    recall_scores.append(current_recall)
    f1_scores.append(current_f1)
# Out:
# For  KN
# Accuracy -  0.6519721577726219
# Precision -  0.4691486540532454
# Recall  -  0.3635197273165727
# F1 Score -  0.390705939733397
# For  NB
# Accuracy -  0.5003866976024749
# Precision -  0.18754607615466842
# Recall  -  0.16685833256325613
# F1 Score -  0.11159986427655748
# For  DT
# Accuracy -  0.5910949066401503
# Precision -  0.36278897391456405
# Recall  -  0.24554553844107932
# F1 Score -  0.2549649839853428
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
# ...

# %%
performance_df = pd.DataFrame({'Algorithm':clfs.keys(),'Accuracy':accuracy_scores,'Precision':precision_scores, 'Recall' : recall_scores, 'F1' : f1_scores}).sort_values('Precision',ascending=False)

# %%
performance_df
# Out:
#    Algorithm  Accuracy  Precision    Recall        F1
# 6        BgC  0.703790   0.580136  0.418190  0.467987
# 4         RF  0.708320   0.573670  0.411187  0.460189
# 7        ETC  0.712297   0.552517  0.414097  0.458841
# 8       GBDT  0.631974   0.507664  0.323378  0.361714
# 0         KN  0.651972   0.469149  0.363520  0.390706
# 9        GNB  0.555298   0.400989  0.373175  0.329779
# 2         DT  0.591095   0.362789  0.245546  0.254965
# 5   AdaBoost  0.154569   0.356267  0.416849  0.116298
# 3         LR  0.585018   0.336417  0.219930  0.217249
# 10       LDA  0.588001   0.302534  0.249758  0.260826
# 1         NB  0.500387   0.187546  0.166858  0.111600

# %%
df['Albuquerque']['weather_description'].unique()
# Out:
# array([nan, 'sky is clear', 'few clouds', 'scattered clouds',
#        'broken clouds', 'overcast clouds', 'light rain', 'moderate rain',
#        'proximity shower rain', 'proximity moderate rain', 'smoke',
#        'light intensity shower rain', 'shower rain', 'mist', 'fog',
#        'heavy snow', 'sand', 'sleet', 'dust', 'light snow',
#        'thunderstorm with light rain', 'thunderstorm', 'haze',
#        'heavy intensity rain', 'squalls', 'thunderstorm with heavy rain',
#        'thunderstorm with rain', 'proximity thunderstorm', 'drizzle',
#        'very heavy rain', 'light intensity drizzle', 'snow',
#        'shower snow', 'proximity thunderstorm with rain',
#        'sand/dust whirls', 'proximity thunderstorm with drizzle',
#        'heavy intensity drizzle', 'thunderstorm with drizzle'],
#       dtype=object)

# %%
# Define the minority class label
minority_class_label = 1

# Get the number of instances in the minority class
minority_class_count = len(dfn['Albuquerque'][dfn['Albuquerque']['weather_desc'] == minority_class_label])

# Undersample each majority class to match the number of instances in the minority class
undersampled_dfs = []
for label, group in dfn['Albuquerque'].groupby('weather_desc'):
    if label != minority_class_label:
        undersampled_group = group.sample(n=minority_class_count, random_state=42)
        undersampled_dfs.append(undersampled_group)

# Combine undersampled majority classes with minority class
undersampled_df = pd.concat([dfn['Albuquerque'][dfn['Albuquerque']['weather_desc'] == minority_class_label]] + undersampled_dfs)

# Shuffle the DataFrame
undersampled_df = undersampled_df.sample(frac=1, random_state=42).reset_index(drop=True)

# Print the undersampled DataFrame
print(undersampled_df)
# Out:
#          month  humidity  pressure  temperature  wind_direction  wind_speed  \
# 0     0.272727  0.736842  0.819672     0.391687        0.000000    0.090909
# 1     0.545455  0.357895  0.864754     0.772836        0.416667    0.181818
# 2     0.909091  0.315789  0.893443     0.413536        0.000000    0.000000
# 3     0.545455  0.757895  0.889344     0.617116        0.777778    0.090909
# 4     0.090909  0.926316  0.901639     0.296342        0.386111    0.136364
# ...        ...       ...       ...          ...             ...         ...
# 1627  1.000000  0.600000  0.909836     0.297527        1.000000    0.090909
# 1628  1.000000  0.726316  0.897541     0.307758        0.830556    0.090909
# 1629  0.000000  0.694737  0.897541     0.308671        0.052778    0.090909
# 1630  0.727273  0.873684  0.856557     0.608099        0.250000    0.090909
# 1631  0.636364  0.926316  0.872951     0.523650        0.419444    0.045455
#
#       weather_desc
# 0                2
# ...

# %%
x = undersampled_df.drop(['weather_desc'], axis=1)
y = undersampled_df['weather_desc']

# %%
x
# Out:
#          month  humidity  pressure  temperature  wind_direction  wind_speed
# 0     0.272727  0.736842  0.819672     0.391687        0.000000    0.090909
# 1     0.545455  0.357895  0.864754     0.772836        0.416667    0.181818
# 2     0.909091  0.315789  0.893443     0.413536        0.000000    0.000000
# 3     0.545455  0.757895  0.889344     0.617116        0.777778    0.090909
# 4     0.090909  0.926316  0.901639     0.296342        0.386111    0.136364
# ...        ...       ...       ...          ...             ...         ...
# 1627  1.000000  0.600000  0.909836     0.297527        1.000000    0.090909
# 1628  1.000000  0.726316  0.897541     0.307758        0.830556    0.090909
# 1629  0.000000  0.694737  0.897541     0.308671        0.052778    0.090909
# 1630  0.727273  0.873684  0.856557     0.608099        0.250000    0.090909
# 1631  0.636364  0.926316  0.872951     0.523650        0.419444    0.045455
#
# [1632 rows x 6 columns]

# %%
y
# Out:
# 0       2
# 1       5
# 2       0
# 3       0
# 4       3
#        ..
# 1627    4
# 1628    4
# 1629    3
# 1630    5
# 1631    4
# Name: weather_desc, Length: 1632, dtype: int64

# %%
y.unique()
# Out:
# array([2, 5, 0, 3, 4, 1])

# %%
y.value_counts()
# Out:
# weather_desc
# 2    272
# 5    272
# 0    272
# 3    272
# 4    272
# 1    272
# Name: count, dtype: int64

# %%
X_train,X_test,y_train,y_test = train_test_split(x,y,test_size=0.2,random_state=2)

# %%
svc = SVC(kernel='sigmoid', gamma=1.0)
knc = KNeighborsClassifier()
mnb = MultinomialNB()
dtc = DecisionTreeClassifier(max_depth=5)
lrc = LogisticRegression(solver='liblinear', penalty='l1')
rfc = RandomForestClassifier(n_estimators=50, random_state=2)
abc = AdaBoostClassifier(n_estimators=50, random_state=2)
bc = BaggingClassifier(n_estimators=50, random_state=2)
etc = ExtraTreesClassifier(n_estimators=50, random_state=2)
gbdt = GradientBoostingClassifier(n_estimators=50,random_state=2)
gnb = GaussianNB()
lda  = LinearDiscriminantAnalysis()

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score

# %%
clfs = {
    #'SVC' : svc,
    'KN' : knc,
    'NB': mnb,
    'DT': dtc,
    'LR': lrc,
    'RF': rfc,
    'AdaBoost': abc,
    'BgC': bc,
    'ETC': etc,
    'GBDT':gbdt,
    'GNB' :gnb,
    'LDA' : lda,
}

# %%
def train_classifier(clf,X_train,y_train,X_test,y_test):
    clf.fit(X_train,y_train)
    y_pred = clf.predict(X_test)
    accuracy = accuracy_score(y_test,y_pred)
    precision = precision_score(y_test,y_pred, average='macro')
    recall = recall_score(y_test,y_pred, average='macro')
    f1 = f1_score(y_test,y_pred, average='macro')
    return accuracy,precision, recall, f1

# %%
accuracy_scores = []
precision_scores = []
recall_scores = []
f1_scores = []

for name,clf in clfs.items():
    current_accuracy,current_precision, current_recall, current_f1 = train_classifier(clf, X_train,y_train,X_test,y_test)

    print("For ",name)
    print("Accuracy - ",current_accuracy)
    print("Precision - ",current_precision)
    print("Recall  - ", current_recall)
    print("F1 Score - ", current_f1)

    accuracy_scores.append(current_accuracy)
    precision_scores.append(current_precision)
    recall_scores.append(current_recall)
    f1_scores.append(current_f1)
# Out:
# For  KN
# Accuracy -  0.4954128440366973
# Precision -  0.4942357116678007
# Recall  -  0.4945221850923605
# F1 Score -  0.4916669830327481
# For  NB
# Accuracy -  0.40672782874617736
# Precision -  0.4145354401731907
# Recall  -  0.41013509014081095
# F1 Score -  0.3840791233101461
# For  DT
# Accuracy -  0.5045871559633027
# Precision -  0.5596829320522131
# Recall  -  0.5029717510362056
# F1 Score -  0.4959496116058573
# For  LR
# Accuracy -  0.44036697247706424
# Precision -  0.41644861908260616
# Recall  -  0.4479275382498113
# F1 Score -  0.41292187343622055
# For  RF
# Accuracy -  0.5626911314984709
# Precision -  0.5549860888843939
# Recall  -  0.5639281880223909
# F1 Score -  0.5516373738297883
# For  AdaBoost
# Accuracy -  0.3394495412844037
# Precision -  0.4402878622379304
# Recall  -  0.33310929295864455
# F1 Score -  0.30948586522005084
# For  BgC
# Accuracy -  0.5504587155963303
# Precision -  0.551170305818789
# Recall  -  0.5528913366346623
# ...

# %%
performance_df = pd.DataFrame({'Algorithm':clfs.keys(),'Accuracy':accuracy_scores,'Precision':precision_scores, 'Recall' : recall_scores, 'F1' : f1_scores}).sort_values('Precision',ascending=False)

# %%
performance_df
# Out:
#    Algorithm  Accuracy  Precision    Recall        F1
# 2         DT  0.504587   0.559683  0.502972  0.495950
# 4         RF  0.562691   0.554986  0.563928  0.551637
# 6        BgC  0.550459   0.551170  0.552891  0.539798
# 7        ETC  0.556575   0.549035  0.557734  0.546378
# 8       GBDT  0.550459   0.544121  0.554102  0.538467
# 0         KN  0.495413   0.494236  0.494522  0.491667
# 9        GNB  0.440367   0.471721  0.450282  0.394504
# 5   AdaBoost  0.339450   0.440288  0.333109  0.309486
# 10       LDA  0.431193   0.420363  0.434602  0.422295
# 3         LR  0.440367   0.416449  0.447928  0.412922
# 1         NB  0.406728   0.414535  0.410135  0.384079

# %%
df['Albuquerque']['weather_description'].unique()
# Out:
# array([nan, 'sky is clear', 'few clouds', 'scattered clouds',
#        'broken clouds', 'overcast clouds', 'light rain', 'moderate rain',
#        'proximity shower rain', 'proximity moderate rain', 'smoke',
#        'light intensity shower rain', 'shower rain', 'mist', 'fog',
#        'heavy snow', 'sand', 'sleet', 'dust', 'light snow',
#        'thunderstorm with light rain', 'thunderstorm', 'haze',
#        'heavy intensity rain', 'squalls', 'thunderstorm with heavy rain',
#        'thunderstorm with rain', 'proximity thunderstorm', 'drizzle',
#        'very heavy rain', 'light intensity drizzle', 'snow',
#        'shower snow', 'proximity thunderstorm with rain',
#        'sand/dust whirls', 'proximity thunderstorm with drizzle',
#        'heavy intensity drizzle', 'thunderstorm with drizzle'],
#       dtype=object)

# %%
def map_classes(target):
    if type(target) == float:
        target = str(target)
    if 'squall' in target or 'thunderstorm' in target:
        return 'thunderstorm'
    elif 'drizzle' in target or 'rain' in target or 'sleet' in target or 'snow' in target:
        return 'precipitation'
    elif 'cloud' in target or 'fog' in target or 'mist' in target or 'haze' in target:
        return 'not_clear_sky'
    elif 'sun' in target or 'clear' in target:
        return 'sunny'

# Apply the mapping function to create a new target variable with decreased classes
df['Albuquerque']['weather_desc2'] = df['Albuquerque']['weather_description'].apply(map_classes)

# Display the DataFrame with the new target variable
print(df['Albuquerque'])
# Out:
#        month   humidity  pressure  temperature  wind_direction  wind_speed  \
# 0         10  45.186157    1021.0          NaN             NaN         NaN
# 1         10  50.000000    1024.0   285.120000           360.0         4.0
# 2         10  49.000000    1024.0   285.154558           360.0         4.0
# 3         10  49.000000    1024.0   285.233952           360.0         4.0
# 4         10  49.000000    1024.0   285.313345           360.0         4.0
# ...      ...        ...       ...          ...             ...         ...
# 45248     11  37.000000    1025.0   285.720000           217.0         1.0
# 45249     11  34.000000    1024.0   286.450000           217.0         1.0
# 45250     11  32.000000    1024.0   286.440000           190.0         1.0
# 45251     11  30.000000    1024.0   286.140000           200.0         1.0
# 45252     11  34.000000    1024.0   284.700000           230.0         2.0
#
#       weather_description weather_desc  weather_desc2
# ...

# %%
df['Albuquerque']['weather_desc2'].unique()
# Out:
# array([None, 'sunny', 'not_clear_sky', 'precipitation', 'thunderstorm'],
#       dtype=object)

# %%
dfn['Albuquerque'] = copy.deepcopy(df['Albuquerque'])
dfn['Albuquerque']
# Out:
#        month   humidity  pressure  temperature  wind_direction  wind_speed  \
# 0         10  45.186157    1021.0          NaN             NaN         NaN
# 1         10  50.000000    1024.0   285.120000           360.0         4.0
# 2         10  49.000000    1024.0   285.154558           360.0         4.0
# 3         10  49.000000    1024.0   285.233952           360.0         4.0
# 4         10  49.000000    1024.0   285.313345           360.0         4.0
# ...      ...        ...       ...          ...             ...         ...
# 45248     11  37.000000    1025.0   285.720000           217.0         1.0
# 45249     11  34.000000    1024.0   286.450000           217.0         1.0
# 45250     11  32.000000    1024.0   286.440000           190.0         1.0
# 45251     11  30.000000    1024.0   286.140000           200.0         1.0
# 45252     11  34.000000    1024.0   284.700000           230.0         2.0
#
#       weather_description weather_desc  weather_desc2
# ...

# %%
dfn['Albuquerque'] = dfn['Albuquerque'].drop(columns = ['weather_description', 'weather_desc'])
dfn['Albuquerque']
# Out:
#        month   humidity  pressure  temperature  wind_direction  wind_speed  \
# 0         10  45.186157    1021.0          NaN             NaN         NaN
# 1         10  50.000000    1024.0   285.120000           360.0         4.0
# 2         10  49.000000    1024.0   285.154558           360.0         4.0
# 3         10  49.000000    1024.0   285.233952           360.0         4.0
# 4         10  49.000000    1024.0   285.313345           360.0         4.0
# ...      ...        ...       ...          ...             ...         ...
# 45248     11  37.000000    1025.0   285.720000           217.0         1.0
# 45249     11  34.000000    1024.0   286.450000           217.0         1.0
# 45250     11  32.000000    1024.0   286.440000           190.0         1.0
# 45251     11  30.000000    1024.0   286.140000           200.0         1.0
# 45252     11  34.000000    1024.0   284.700000           230.0         2.0
#
#        weather_desc2
# 0               None
# 1              sunny
# ...

# %%
for df_name, datafr in dfn.items():
    for column in datafr.columns:
        if column=='weather_desc2':
            dfn[df_name][column] = dfn[df_name][column].fillna(dfn[df_name][column].mode()[0])
        else:
            dfn[df_name][column] = dfn[df_name][column].fillna(dfn[df_name][column].median())

# %%
dfn['Albuquerque']['weather_desc2']
# Out:
# 0        not_clear_sky
# 1                sunny
# 2                sunny
# 3                sunny
# 4                sunny
#              ...
# 45248    not_clear_sky
# 45249    not_clear_sky
# 45250    not_clear_sky
# 45251    not_clear_sky
# 45252    not_clear_sky
# Name: weather_desc2, Length: 45253, dtype: object

# %%
#from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import MinMaxScaler

# Create MinMaxScaler instance
scaler = MinMaxScaler()
#scaler = StandardScaler()
label = LabelEncoder()

# %%
for df_name, datafr in dfn.items():
    for column in datafr.columns:
        if column=='weather_desc2':
            dfn[df_name][column] = label.fit_transform(dfn[df_name][column].values.reshape(-1, 1))
        else:
            dfn[df_name][column] = scaler.fit_transform(dfn[df_name][column].values.reshape(-1, 1))
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/preprocessing/_label.py:116: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)

# %%
dfn['Albuquerque']
# Out:
#           month  humidity  pressure  temperature  wind_direction  wind_speed  \
# 0      0.818182  0.423012  0.864754     0.538910        0.583333    0.090909
# 1      0.818182  0.473684  0.877049     0.521569        1.000000    0.181818
# 2      0.818182  0.463158  0.877049     0.522168        1.000000    0.181818
# 3      0.818182  0.463158  0.877049     0.523545        1.000000    0.181818
# 4      0.818182  0.463158  0.877049     0.524922        1.000000    0.181818
# ...         ...       ...       ...          ...             ...         ...
# 45248  0.909091  0.336842  0.881148     0.531973        0.602778    0.045455
# 45249  0.909091  0.305263  0.877049     0.544632        0.602778    0.045455
# 45250  0.909091  0.284211  0.877049     0.544459        0.527778    0.045455
# 45251  0.909091  0.263158  0.877049     0.539257        0.555556    0.045455
# 45252  0.909091  0.305263  0.877049     0.514286        0.638889    0.090909
#
#        weather_desc2
# 0                  0
# ...

# %%
alb2 = copy.deepcopy(dfn['Albuquerque'])
alb2
# Out:
#           month  humidity  pressure  temperature  wind_direction  wind_speed  \
# 0      0.818182  0.423012  0.864754     0.538910        0.583333    0.090909
# 1      0.818182  0.473684  0.877049     0.521569        1.000000    0.181818
# 2      0.818182  0.463158  0.877049     0.522168        1.000000    0.181818
# 3      0.818182  0.463158  0.877049     0.523545        1.000000    0.181818
# 4      0.818182  0.463158  0.877049     0.524922        1.000000    0.181818
# ...         ...       ...       ...          ...             ...         ...
# 45248  0.909091  0.336842  0.881148     0.531973        0.602778    0.045455
# 45249  0.909091  0.305263  0.877049     0.544632        0.602778    0.045455
# 45250  0.909091  0.284211  0.877049     0.544459        0.527778    0.045455
# 45251  0.909091  0.263158  0.877049     0.539257        0.555556    0.045455
# 45252  0.909091  0.305263  0.877049     0.514286        0.638889    0.090909
#
#        weather_desc2
# 0                  0
# ...

# %%
x = alb2.drop(['weather_desc2'], axis=1)
y = alb2['weather_desc2']

# %%
x
# Out:
#           month  humidity  pressure  temperature  wind_direction  wind_speed
# 0      0.818182  0.423012  0.864754     0.538910        0.583333    0.090909
# 1      0.818182  0.473684  0.877049     0.521569        1.000000    0.181818
# 2      0.818182  0.463158  0.877049     0.522168        1.000000    0.181818
# 3      0.818182  0.463158  0.877049     0.523545        1.000000    0.181818
# 4      0.818182  0.463158  0.877049     0.524922        1.000000    0.181818
# ...         ...       ...       ...          ...             ...         ...
# 45248  0.909091  0.336842  0.881148     0.531973        0.602778    0.045455
# 45249  0.909091  0.305263  0.877049     0.544632        0.602778    0.045455
# 45250  0.909091  0.284211  0.877049     0.544459        0.527778    0.045455
# 45251  0.909091  0.263158  0.877049     0.539257        0.555556    0.045455
# 45252  0.909091  0.305263  0.877049     0.514286        0.638889    0.090909
#
# [45253 rows x 6 columns]

# %%
y
# Out:
# 0        0
# 1        2
# 2        2
# 3        2
# 4        2
#         ..
# 45248    0
# 45249    0
# 45250    0
# 45251    0
# 45252    0
# Name: weather_desc2, Length: 45253, dtype: int64

# %%
y.unique()
# Out:
# array([0, 2, 1, 3])

# %%
X_train,X_test,y_train,y_test = train_test_split(x,y,test_size=0.2,random_state=2)

# %%
svc = SVC(kernel='sigmoid', gamma=1.0)
knc = KNeighborsClassifier()
mnb = MultinomialNB()
dtc = DecisionTreeClassifier(max_depth=5)
lrc = LogisticRegression(solver='liblinear', penalty='l1')
rfc = RandomForestClassifier(n_estimators=50, random_state=2)
abc = AdaBoostClassifier(n_estimators=50, random_state=2)
bc = BaggingClassifier(n_estimators=50, random_state=2)
etc = ExtraTreesClassifier(n_estimators=50, random_state=2)
gbdt = GradientBoostingClassifier(n_estimators=50,random_state=2)
gnb = GaussianNB()
lda  = LinearDiscriminantAnalysis()

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score

# %%
clfs = {
    #'SVC' : svc,
    'KN' : knc,
    'NB': mnb,
    'DT': dtc,
    'LR': lrc,
    'RF': rfc,
    'AdaBoost': abc,
    'BgC': bc,
    'ETC': etc,
    'GBDT':gbdt,
    'GNB' :gnb,
    'LDA' : lda,
}

# %%
def train_classifier(clf,X_train,y_train,X_test,y_test):
    clf.fit(X_train,y_train)
    y_pred = clf.predict(X_test)
    accuracy = accuracy_score(y_test,y_pred)
    precision = precision_score(y_test,y_pred, average='macro')
    recall = recall_score(y_test,y_pred, average='macro')
    f1 = f1_score(y_test,y_pred, average='macro')
    return accuracy,precision, recall, f1

# %%
accuracy_scores = []
precision_scores = []
recall_scores = []
f1_scores = []

for name,clf in clfs.items():
    current_accuracy,current_precision, current_recall, current_f1 = train_classifier(clf, X_train,y_train,X_test,y_test)

    print("For ",name)
    print("Accuracy - ",current_accuracy)
    print("Precision - ",current_precision)
    print("Recall  - ", current_recall)
    print("F1 Score - ", current_f1)

    accuracy_scores.append(current_accuracy)
    precision_scores.append(current_precision)
    recall_scores.append(current_recall)
    f1_scores.append(current_f1)
# Out:
# For  KN
# Accuracy -  0.6581593194122196
# Precision -  0.5143916492335471
# Recall  -  0.4276894169588553
# F1 Score -  0.44476557329727373
# For  NB
# Accuracy -  0.5056899790078444
# Precision -  0.3763951817880429
# Recall  -  0.2501370989854675
# F1 Score -  0.16817627904072688
# For  DT
# Accuracy -  0.600596619158104
# Precision -  0.43878577167959465
# Recall  -  0.35002994836701395
# F1 Score -  0.35639964303359384
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
# ...

# %%
performance_df = pd.DataFrame({'Algorithm':clfs.keys(),'Accuracy':accuracy_scores,'Precision':precision_scores, 'Recall' : recall_scores, 'F1' : f1_scores}).sort_values('Precision',ascending=False)

# %%
performance_df
# Out:
#    Algorithm  Accuracy  Precision    Recall        F1
# 4         RF  0.713623   0.593778  0.467825  0.495952
# 6        BgC  0.701911   0.566882  0.461698  0.485763
# 7        ETC  0.717490   0.550793  0.470433  0.493174
# 8       GBDT  0.634626   0.515092  0.376554  0.391516
# 0         KN  0.658159   0.514392  0.427689  0.444766
# 5   AdaBoost  0.574633   0.479078  0.347215  0.353560
# 10       LDA  0.590763   0.465514  0.376857  0.397073
# 2         DT  0.600597   0.438786  0.350030  0.356400
# 9        GNB  0.569992   0.438243  0.393844  0.392355
# 3         LR  0.590763   0.402731  0.329919  0.326574
# 1         NB  0.505690   0.376395  0.250137  0.168176

# %%
df['Albuquerque']['weather_description'].unique()
# Out:
# array([nan, 'sky is clear', 'few clouds', 'scattered clouds',
#        'broken clouds', 'overcast clouds', 'light rain', 'moderate rain',
#        'proximity shower rain', 'proximity moderate rain', 'smoke',
#        'light intensity shower rain', 'shower rain', 'mist', 'fog',
#        'heavy snow', 'sand', 'sleet', 'dust', 'light snow',
#        'thunderstorm with light rain', 'thunderstorm', 'haze',
#        'heavy intensity rain', 'squalls', 'thunderstorm with heavy rain',
#        'thunderstorm with rain', 'proximity thunderstorm', 'drizzle',
#        'very heavy rain', 'light intensity drizzle', 'snow',
#        'shower snow', 'proximity thunderstorm with rain',
#        'sand/dust whirls', 'proximity thunderstorm with drizzle',
#        'heavy intensity drizzle', 'thunderstorm with drizzle'],
#       dtype=object)

# %%
def map_classes(target):
    if type(target) == float:
        target = str(target)
    if 'squall' in target or 'thunderstorm' in target or 'drizzle' in target or 'rain' in target or 'sleet' in target or 'snow' in target or 'cloud' in target:
        return 'chance_precipitation'
    elif 'sun' in target or 'clear' in target or 'fog' in target or 'mist' in target or 'haze' in target:
        return 'no_precipitation'

# Apply the mapping function to create a new target variable with decreased classes
df['Albuquerque']['weather_desc3'] = df['Albuquerque']['weather_description'].apply(map_classes)

# Display the DataFrame with the new target variable
print(df['Albuquerque'])
# Out:
#        month   humidity  pressure  temperature  wind_direction  wind_speed  \
# 0         10  45.186157    1021.0          NaN             NaN         NaN
# 1         10  50.000000    1024.0   285.120000           360.0         4.0
# 2         10  49.000000    1024.0   285.154558           360.0         4.0
# 3         10  49.000000    1024.0   285.233952           360.0         4.0
# 4         10  49.000000    1024.0   285.313345           360.0         4.0
# ...      ...        ...       ...          ...             ...         ...
# 45248     11  37.000000    1025.0   285.720000           217.0         1.0
# 45249     11  34.000000    1024.0   286.450000           217.0         1.0
# 45250     11  32.000000    1024.0   286.440000           190.0         1.0
# 45251     11  30.000000    1024.0   286.140000           200.0         1.0
# 45252     11  34.000000    1024.0   284.700000           230.0         2.0
#
# ...

# %%
df['Albuquerque']['weather_desc3'].unique()
# Out:
# array([None, 'no_precipitation', 'chance_precipitation'], dtype=object)

# %%
dfn['Albuquerque'] = copy.deepcopy(df['Albuquerque'])
dfn['Albuquerque']
# Out:
#        month   humidity  pressure  temperature  wind_direction  wind_speed  \
# 0         10  45.186157    1021.0          NaN             NaN         NaN
# 1         10  50.000000    1024.0   285.120000           360.0         4.0
# 2         10  49.000000    1024.0   285.154558           360.0         4.0
# 3         10  49.000000    1024.0   285.233952           360.0         4.0
# 4         10  49.000000    1024.0   285.313345           360.0         4.0
# ...      ...        ...       ...          ...             ...         ...
# 45248     11  37.000000    1025.0   285.720000           217.0         1.0
# 45249     11  34.000000    1024.0   286.450000           217.0         1.0
# 45250     11  32.000000    1024.0   286.440000           190.0         1.0
# 45251     11  30.000000    1024.0   286.140000           200.0         1.0
# 45252     11  34.000000    1024.0   284.700000           230.0         2.0
#
# ...

# %%
dfn['Albuquerque'] = dfn['Albuquerque'].drop(columns = ['weather_description', 'weather_desc', 'weather_desc2'])
dfn['Albuquerque']
# Out:
#        month   humidity  pressure  temperature  wind_direction  wind_speed  \
# 0         10  45.186157    1021.0          NaN             NaN         NaN
# 1         10  50.000000    1024.0   285.120000           360.0         4.0
# 2         10  49.000000    1024.0   285.154558           360.0         4.0
# 3         10  49.000000    1024.0   285.233952           360.0         4.0
# 4         10  49.000000    1024.0   285.313345           360.0         4.0
# ...      ...        ...       ...          ...             ...         ...
# 45248     11  37.000000    1025.0   285.720000           217.0         1.0
# 45249     11  34.000000    1024.0   286.450000           217.0         1.0
# 45250     11  32.000000    1024.0   286.440000           190.0         1.0
# 45251     11  30.000000    1024.0   286.140000           200.0         1.0
# 45252     11  34.000000    1024.0   284.700000           230.0         2.0
#
#               weather_desc3
# 0                      None
# ...

# %%
for df_name, datafr in dfn.items():
    for column in datafr.columns:
        if column=='weather_desc3':
            dfn[df_name][column] = dfn[df_name][column].fillna(dfn[df_name][column].mode()[0])
        else:
            dfn[df_name][column] = dfn[df_name][column].fillna(dfn[df_name][column].median())

# %%
dfn['Albuquerque']['weather_desc3']
# Out:
# 0        chance_precipitation
# 1            no_precipitation
# 2            no_precipitation
# 3            no_precipitation
# 4            no_precipitation
#                  ...
# 45248    chance_precipitation
# 45249    chance_precipitation
# 45250    chance_precipitation
# 45251    chance_precipitation
# 45252    chance_precipitation
# Name: weather_desc3, Length: 45253, dtype: object

# %%
#from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import MinMaxScaler

# Create MinMaxScaler instance
scaler = MinMaxScaler()
#scaler = StandardScaler()
label = LabelEncoder()

# %%
for df_name, datafr in dfn.items():
    for column in datafr.columns:
        if column=='weather_desc3':
            dfn[df_name][column] = label.fit_transform(dfn[df_name][column].values.reshape(-1, 1))
        else:
            dfn[df_name][column] = scaler.fit_transform(dfn[df_name][column].values.reshape(-1, 1))
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/preprocessing/_label.py:116: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)

# %%
dfn['Albuquerque']
# Out:
#           month  humidity  pressure  temperature  wind_direction  wind_speed  \
# 0      0.818182  0.423012  0.864754     0.538910        0.583333    0.090909
# 1      0.818182  0.473684  0.877049     0.521569        1.000000    0.181818
# 2      0.818182  0.463158  0.877049     0.522168        1.000000    0.181818
# 3      0.818182  0.463158  0.877049     0.523545        1.000000    0.181818
# 4      0.818182  0.463158  0.877049     0.524922        1.000000    0.181818
# ...         ...       ...       ...          ...             ...         ...
# 45248  0.909091  0.336842  0.881148     0.531973        0.602778    0.045455
# 45249  0.909091  0.305263  0.877049     0.544632        0.602778    0.045455
# 45250  0.909091  0.284211  0.877049     0.544459        0.527778    0.045455
# 45251  0.909091  0.263158  0.877049     0.539257        0.555556    0.045455
# 45252  0.909091  0.305263  0.877049     0.514286        0.638889    0.090909
#
#        weather_desc3
# 0                  0
# ...

# %%
alb3 = copy.deepcopy(dfn['Albuquerque'])
alb3
# Out:
#           month  humidity  pressure  temperature  wind_direction  wind_speed  \
# 0      0.818182  0.423012  0.864754     0.538910        0.583333    0.090909
# 1      0.818182  0.473684  0.877049     0.521569        1.000000    0.181818
# 2      0.818182  0.463158  0.877049     0.522168        1.000000    0.181818
# 3      0.818182  0.463158  0.877049     0.523545        1.000000    0.181818
# 4      0.818182  0.463158  0.877049     0.524922        1.000000    0.181818
# ...         ...       ...       ...          ...             ...         ...
# 45248  0.909091  0.336842  0.881148     0.531973        0.602778    0.045455
# 45249  0.909091  0.305263  0.877049     0.544632        0.602778    0.045455
# 45250  0.909091  0.284211  0.877049     0.544459        0.527778    0.045455
# 45251  0.909091  0.263158  0.877049     0.539257        0.555556    0.045455
# 45252  0.909091  0.305263  0.877049     0.514286        0.638889    0.090909
#
#        weather_desc3
# 0                  0
# ...

# %%
x = alb3.drop(['weather_desc3'], axis=1)
y = alb3['weather_desc3']

# %%
x
# Out:
#           month  humidity  pressure  temperature  wind_direction  wind_speed
# 0      0.818182  0.423012  0.864754     0.538910        0.583333    0.090909
# 1      0.818182  0.473684  0.877049     0.521569        1.000000    0.181818
# 2      0.818182  0.463158  0.877049     0.522168        1.000000    0.181818
# 3      0.818182  0.463158  0.877049     0.523545        1.000000    0.181818
# 4      0.818182  0.463158  0.877049     0.524922        1.000000    0.181818
# ...         ...       ...       ...          ...             ...         ...
# 45248  0.909091  0.336842  0.881148     0.531973        0.602778    0.045455
# 45249  0.909091  0.305263  0.877049     0.544632        0.602778    0.045455
# 45250  0.909091  0.284211  0.877049     0.544459        0.527778    0.045455
# 45251  0.909091  0.263158  0.877049     0.539257        0.555556    0.045455
# 45252  0.909091  0.305263  0.877049     0.514286        0.638889    0.090909
#
# [45253 rows x 6 columns]

# %%
y
# Out:
# 0        0
# 1        1
# 2        1
# 3        1
# 4        1
#         ..
# 45248    0
# 45249    0
# 45250    0
# 45251    0
# 45252    0
# Name: weather_desc3, Length: 45253, dtype: int64

# %%
y.unique()
# Out:
# array([0, 1])

# %%
X_train,X_test,y_train,y_test = train_test_split(x,y,test_size=0.2,random_state=2)

# %%
svc = SVC(kernel='sigmoid', gamma=1.0)
knc = KNeighborsClassifier()
mnb = MultinomialNB()
dtc = DecisionTreeClassifier(max_depth=5)
lrc = LogisticRegression(solver='liblinear', penalty='l1')
rfc = RandomForestClassifier(n_estimators=50, random_state=2)
abc = AdaBoostClassifier(n_estimators=50, random_state=2)
bc = BaggingClassifier(n_estimators=50, random_state=2)
etc = ExtraTreesClassifier(n_estimators=50, random_state=2)
gbdt = GradientBoostingClassifier(n_estimators=50,random_state=2)
gnb = GaussianNB()
lda  = LinearDiscriminantAnalysis()

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score

# %%
clfs = {
    #'SVC' : svc,
    'KN' : knc,
    'NB': mnb,
    'DT': dtc,
    'LR': lrc,
    'RF': rfc,
    'AdaBoost': abc,
    'BgC': bc,
    'ETC': etc,
    'GBDT':gbdt,
    'GNB' :gnb,
    'LDA' : lda,
}

# %%
def train_classifier(clf,X_train,y_train,X_test,y_test):
    clf.fit(X_train,y_train)
    y_pred = clf.predict(X_test)
    accuracy = accuracy_score(y_test,y_pred)
    precision = precision_score(y_test,y_pred, average='macro')
    recall = recall_score(y_test,y_pred, average='macro')
    f1 = f1_score(y_test,y_pred, average='macro')
    return accuracy,precision, recall, f1

# %%
accuracy_scores = []
precision_scores = []
recall_scores = []
f1_scores = []

for name,clf in clfs.items():
    current_accuracy,current_precision, current_recall, current_f1 = train_classifier(clf, X_train,y_train,X_test,y_test)

    print("For ",name)
    print("Accuracy - ",current_accuracy)
    print("Precision - ",current_precision)
    print("Recall  - ", current_recall)
    print("F1 Score - ", current_f1)

    accuracy_scores.append(current_accuracy)
    precision_scores.append(current_precision)
    recall_scores.append(current_recall)
    f1_scores.append(current_f1)
# Out:
# For  KN
# Accuracy -  0.7212462711302619
# Precision -  0.7115604422502398
# Recall  -  0.7054057197281282
# F1 Score -  0.7076483654901479
# For  NB
# Accuracy -  0.5915368467572644
# Precision -  0.2957684233786322
# Recall  -  0.5
# F1 Score -  0.37167650121485596
# For  DT
# Accuracy -  0.6761683791846205
# Precision -  0.6816598000283648
# Recall  -  0.6294230781472403
# F1 Score -  0.6246214993826701
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# For  LR
# Accuracy -  0.671307037896365
# Precision -  0.6592588342990977
# Recall  -  0.6421403829837498
# F1 Score -  0.6440173999229117
# For  RF
# Accuracy -  0.7711855043641587
# Precision -  0.7674974710083502
# Recall  -  0.7525980944074333
# F1 Score -  0.7572853451703306
# ...

# %%
performance_df = pd.DataFrame({'Algorithm':clfs.keys(),'Accuracy':accuracy_scores,'Precision':precision_scores, 'Recall' : recall_scores, 'F1' : f1_scores}).sort_values('Precision',ascending=False)

# %%
performance_df
# Out:
#    Algorithm  Accuracy  Precision    Recall        F1
# 7        ETC  0.775052   0.772234  0.755992  0.760996
# 4         RF  0.771186   0.767497  0.752598  0.757285
# 6        BgC  0.761352   0.756452  0.742822  0.747123
# 0         KN  0.721246   0.711560  0.705406  0.707648
# 8       GBDT  0.695945   0.694003  0.660162  0.662140
# 2         DT  0.676168   0.681660  0.629423  0.624621
# 5   AdaBoost  0.685560   0.675448  0.657620  0.660236
# 3         LR  0.671307   0.659259  0.642140  0.644017
# 10       LDA  0.670644   0.658685  0.640868  0.642633
# 9        GNB  0.652193   0.642137  0.609786  0.605733
# 1         NB  0.591537   0.295768  0.500000  0.371677
